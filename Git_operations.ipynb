# %%
# Databricks Notebook source
# MAGIC %md
# MAGIC # 🔧 OPERAÇÕES GIT - COMMIT DO PROJETO

# COMMAND ----------

# MAGIC %sh
# MAGIC # Navegar para o workspace
# MAGIC cd /Workspace/Users/$USER/financial-dashboard

# COMMAND ----------

# MAGIC %md
# MAGIC ## 1. CONFIGURAR GIT

# COMMAND ----------

# MAGIC %sh
# MAGIC # Configurar usuário Git
# MAGIC git config --global user.name "Seu Nome"
# MAGIC git config --global user.email "seu-email@example.com"

# COMMAND ----------

# MAGIC %md
# MAGIC ## 2. VERIFICAR STATUS

# COMMAND ----------

# MAGIC %sh
# MAGIC cd /Workspace/Users/$USER/financial-dashboard
# MAGIC git status

# COMMAND ----------

# MAGIC %md
# MAGIC ## 3. ADICIONAR ARQUIVOS

# COMMAND ----------

# MAGIC %sh
# MAGIC cd /Workspace/Users/$USER/financial-dashboard
# MAGIC git add .
# MAGIC echo "✅ Arquivos adicionados ao staging"

# COMMAND ----------

# MAGIC %md
# MAGIC ## 4. FAZER COMMIT

# COMMAND ----------

# MAGIC %sh
# MAGIC cd /Workspace/Users/$USER/financial-dashboard
# MAGIC git commit -m "feat: initial commit - financial dashboard system
# MAGIC 
# MAGIC - Data collection from Yahoo Finance
# MAGIC - Data processing with technical indicators
# MAGIC - Databricks dashboard integration
# MAGIC - Project documentation and structure
# MAGIC "
# MAGIC echo "✅ Commit realizado!"

# COMMAND ----------

# MAGIC %md
# MAGIC ## 5. CONFIGURAR REMOTE (SE PRECISAR)

# COMMAND ----------

# MAGIC %sh
# MAGIC cd /Workspace/Users/$USER/financial-dashboard
# MAGIC git remote -v
# MAGIC 
# MAGIC # Se não tiver remote, adicione:
# MAGIC # git remote add origin https://github.com/SEU-USUARIO/financial-dashboard.git

# COMMAND ----------

# MAGIC %md
# MAGIC ## 6. FAZER PUSH

# COMMAND ----------

# MAGIC %sh
# MAGIC cd /Workspace/Users/$USER/financial-dashboard
# MAGIC git push -u origin main
# MAGIC echo "🎉 Push realizado com sucesso!"
